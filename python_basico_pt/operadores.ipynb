# %% [markdown]
# # Operadores

# %% [markdown]
# Antes de ler esse artigo leia o artigo de [variáveis](variaveis.ipynb).

# %% [markdown]
# ## Operadores Aritmeticos (int e float):

# %% [markdown]
# <ul>
#     <li>adição(<strong>+</strong>)
# </ul>

# %% [markdown]
# subtração entre dois numeros inteiro ou float.
# <br>Exemplo:

# %%
# soma de inteiros
numero_a = 5
numero_b = 10
numero_c = numero_a+numero_b
print(numero_c)
# Out:
# 15

# %%
# soma de floats
numero_a = 5.
numero_b = 10.
numero_c = numero_a+numero_b
print(numero_c)
# Out:
# 15.0

# %% [markdown]
# <ul>
# <li>subtração(<strong>-</strong>)
# </ul>

# %% [markdown]
# Subtração entre dois numeros inteiro ou float.
# <br>Exemplo:

# %%
# subtracao de inteiros
numero_a = 5
numero_b = 10
numero_c = numero_a-numero_b
print(numero_c)
# Out:
# -5

# %%
# subtracao de float
numero_a = 5.
numero_b = 10.
numero_c = numero_a-numero_b
print(numero_c)
# Out:
# -5.0

# %% [markdown]
# <ul>
# <li>multiplicação(<strong>*</strong>)
# </ul>

# %% [markdown]
# Multiplicação entre dois numeros inteiro ou float.
# <br>Exemplo:

# %%
numero_a = 5
numero_b = 10
numero_c = numero_a*numero_b
print(numero_c)
# Out:
# 50

# %%
numero_a = 5.
numero_b = 10.
numero_c = numero_a*numero_b
print(numero_c)
# Out:
# 50.0

# %% [markdown]
# <ul>
#     <li>divisão inteira(<strong>//</strong>)
# </ul>

# %% [markdown]
# divisão inteira entre dois numeros inteiro ou float, retorna o valor máximo da divisão exata valores posteriores ao ponto são desconsiderados.
# Exemplo:

# %%
numero_a = 12
numero_b = 10
numero_c = numero_a//numero_b
print(numero_c)
# Out:
# 1

# %%
numero_a = 12.
numero_b = 10.
numero_c = numero_a//numero_b
print(numero_c)
# Out:
# 1.0

# %% [markdown]
# <ul>
#     <li>Resto da divisão (<strong>%</strong>)
# </ul>

# %%
numero_a = 10
numero_b = 10
numero_c = numero_a%numero_b
print(numero_c)
# Out:
# 0

# %%
numero_a = 12
numero_b = 10
numero_c = numero_a%numero_b
print(numero_c)
# Out:
# 2

# %% [markdown]
# <ul>
# <li> divisão(<strong>/</strong>)
# </ul>

# %% [markdown]
# divisão real entre dois numeros inteiro ou float, retorna somente o valor real(float) da divisão.
# <br> Exemplo:

# %%
numero_a = 5
numero_b = 10
numero_c = numero_a/numero_b
print(numero_c)
# Out:
# 0.5

# %%
numero_a = 5.
numero_b = 10.
numero_c = numero_a/numero_b
print(numero_c)
# Out:
# 0.5

# %% [markdown]
# <ul>
# <li> potenciação (<strong>**</strong>)
# </ul>

# %% [markdown]
# potenciação de dois numeros inteiro ou float.
# <br>Exemplos:

# %%
numero_a = 5
numero_b = 2
numero_c = numero_a**numero_b
print(numero_c)
# Out:
# 25

# %%
numero_a = 5.
numero_b = 2.
numero_c = numero_a**numero_b
print(numero_c)
# Out:
# 25.0

# %% [markdown]
# Obs.: Operações mistas entre inteiros e float retornaram valores float.

# %% [markdown]
# ### Operadores de atribuição:

# %% [markdown]
# Definição são operadores que atuam diretamente na propria variavel, antes de utilizar os operadores de atribuição é necessario ter certeza de que a variavel já foi definida anteriormente.
# <br>Exemplo:

# %%
numero = 1
numero +=1
print(numero)
# Out:
# 2

# %% [markdown]
# No exemplo acima:
# <ul>
# <li> Foi declarado uma variável "<strong>numero</strong>" com o valor de <strong>1</strong>;
# <li> depois foi atribuido o valor de 1 a <strong>numero</strong>, <strong>numero</strong> agora está com o valor de 2;
#     <li> impresão do valor do <strong>numero</strong>.
# </ul>

# %% [markdown]
# ### Exemplos de operações de atribuição:

# %% [markdown]
# <ul>
#     <li>adição(<strong>+=</strong>)
# </ul>

# %%
# soma de inteiros
numero = 1
numero += 2
print(numero)
# Out:
# 3

# %%
# soma de float
numero = 1.
numero += 2.
print(numero)
# Out:
# 3.0

# %% [markdown]
# <ul>
#     <li>subtração(<strong>-=</strong>)
# </ul>

# %%
# soma de inteiros
numero = 1
numero -= 2
print(numero)
# Out:
# -1

# %%
# soma de float
numero = 1.
numero -= 2.
print(numero)
# Out:
# -1.0

# %% [markdown]
# <ul>
# <li>multiplicação(<strong>*=</strong>)
# </ul>

# %%
# soma de inteiros
numero = 2
numero *= 3
print(numero)
# Out:
# 6

# %%
# soma de float
numero = 2.
numero *= 3.
print(numero)
# Out:
# 6.0

# %% [markdown]
# <ul>
#     <li>divisão inteira(<strong>//=</strong>)
# </ul>

# %%
# soma de inteiros
numero = 7
numero //= 3
print(numero)
# Out:
# 2

# %%
# soma de float
numero = 7.
numero //= 3.
print(numero)
# Out:
# 2.0

# %% [markdown]
# <ul>
# <li> divisão(<strong>/=</strong>)
# </ul>

# %%
# soma de inteiros
numero = 7
numero /= 3
print(numero)
# Out:
# 2.3333333333333335

# %%
# soma de float
numero = 7.
numero /= 3.
print(numero)
# Out:
# 2.3333333333333335

# %% [markdown]
# <ul>
# <li> potenciação (<strong>**=</strong>)
# </ul>

# %%
# soma de inteiros
numero = 3
numero **= 3
print(numero)
# Out:
# 27

# %%
# soma de float
numero = 3.
numero **= 3.
print(numero)
# Out:
# 27.0

# %% [markdown]
# ## Equivalencia entre operações comuns e operaões com atribuição

# %% [markdown]
# Obs.: essas operações podem ser feitas de maneira similar sem a necessidade de desses operadores.

# %%
numero = 1
numero +=1
print(numero)
# Out:
# 2

# %% [markdown]
# É equivalente a:

# %%
numero = 1
numero = numero + 1
print(numero)
# Out:
# 2

# %% [markdown]
# ## Operadores de comparação:

# %% [markdown]
# Definição: basicamente servem para fazer comparações entre valores entre duas variaveis, retornando o resultado da afirmação sendo verdadeira(**True**) ou falsa(**False**). Esse conseito é muito util na implementção de extruturas condicionais.

# %% [markdown]
# **Operador de comparação de quivalencia(==):**
# <br>compara se os valores das variaveis são equivalentes.

# %%
numero_a = 1
numero_b = 1
resultado = numero_a==numero_b
print(resultado)
# Out:
# True

# %%
numero_a = 1
numero_b = 2
resultado = numero_a==numero_b
print(resultado)
# Out:
# False

# %% [markdown]
# **Operador de comparação maior(>):**
# <br>compara se o valor a esquerda é maior do que o da direita.

# %%
numero_a = 1
numero_b = 1
resultado = numero_a>numero_b
print(resultado)
# Out:
# False

# %%
numero_a = 2
numero_b = 1
resultado = numero_a>numero_b
print(resultado)
# Out:
# True

# %% [markdown]
# **Operador de comparação menor(<):**
# <br>compara se os valores das variaveis são equivalentes.

# %%
numero_a = 1
numero_b = 1
resultado = numero_a<numero_b
print(resultado)
# Out:
# False

# %%
numero_a = 0
numero_b = 1
resultado = numero_a<numero_b
print(resultado)
# Out:
# True

# %% [markdown]
# **Operador de comparação maior igual(>=):**
# <br>compara se os valores das variaveis são equivalentes ou maior.

# %%
numero_a = 2
numero_b = 1
resultado = numero_a>=numero_b
print(resultado)
# Out:
# True

# %%
numero_a = 1
numero_b = 1
resultado = numero_a>=numero_b
print(resultado)
# Out:
# True

# %%
numero_a = 1
numero_b = 2
resultado = numero_a>=numero_b
print(resultado)
# Out:
# False

# %% [markdown]
# **Operador de comparação menor igual(<=):**
# <br>compara se os valores das variaveis são equivalentes ou menor.

# %%
numero_a = 1
numero_b = 1
resultado = numero_a<=numero_b
print(resultado)
# Out:
# True

# %%
numero_a = 1
numero_b = 2
resultado = numero_a<=numero_b
print(resultado)
# Out:
# True

# %%
numero_a = 2
numero_b = 1
resultado = numero_a<=numero_b
print(resultado)
# Out:
# False

# %% [markdown]
# **Operador de comparação de diferente(!=):**
# <br>compara se os valores das variaveis não são equivalentes ou melhor se são diferentes.

# %%
numero_a = 2
numero_b = 1
resultado = numero_a!=numero_b
print(resultado)
# Out:
# True

# %%
numero_a = 1
numero_b = 1
resultado = numero_a!=numero_b
print(resultado)
# Out:
# False

# %% [markdown]
# **Warning!!!**

# %% [markdown]
# Obs.: **True** e **False** são nomes reservados do python True e False significam variaveis do tipo boleano, vide o arquivo de variaveis.ipynb

# %% [markdown]
# Obs.: Não confunda o operador de quivalencia (**==**) com o operador de atribuição de valor a variavel (**=**), se for confundido você não fará a comparação, mas sobrescreverá a variavel com um novo valor.

# %% [markdown]
# ### Operador and (e):

# %% [markdown]
# O operador **and** serve para validar duas afirmações, se caso uma afirmação for verdadeira e outra for verdadeira ele retorna **True** e se for em outra situação ele retorna um **False**

# %% [markdown]
# Ex.:

# %%
1==1 and 2==2
# Out:
# True

# %%
1<1 and 2==2
# Out:
# False

# %%
1==1 and 2<2
# Out:
# False

# %%
1<1 and 2<2
# Out:
# False

# %% [markdown]
# ### Operador or (ou):

# %% [markdown]
# O operador **and** serve para validar duas afirmações, se caso qualquer umada das afirmações forem verdadeiras ele retorna **True** e só é retornado false se as duas afirmações forem falsas dai ele retorna um **False**

# %% [markdown]
# Ex.:

# %%
1==1 or 2==2
# Out:
# True

# %%
1<1 or 2==2
# Out:
# True

# %%
1==1 or 2<2
# Out:
# True

# %%
1<1 or 2<2
# Out:
# False

# %% [markdown]
# ### Operador or(ou):

# %% [markdown]
# ## Operações com Strings:

# %% [markdown]
# -  **concatenador(+):**

# %%
palavra_a = 'quadrado'
palavra_b = 'retangulo'
palavra_c = palavra_a+palavra_b
print(palavra_c)
# Out:
# quadradoretangulo

# %% [markdown]
# - **concatenador por atribuição(+=):**

# %%
palavra_a = 'quadrado'
palavra_b = 'retangulo'
palavra_a += palavra_b
print(palavra_a)
# Out:
# quadradoretangulo

# %% [markdown]
# <ul>
# <li><strong>comparador de equivalência(==):</strong>
# </ul>
# <br> verifica se cada caracter pertencente ao string são equivalentes levando em conta a posição também.
# <br>exemplo:

# %%
palavra_a = 'quadrado'
palavra_b = 'quadrado'
resultado = palavra_a == palavra_b
print(resultado)
# Out:
# True

# %%
palavra_a = 'quadrado'
palavra_b = 'retangulo'
resultado = palavra_a == palavra_b
print(resultado)
# Out:
# False

# %%
palavra_a = 'quadrado'
palavra_b = 'Quadrado'
resultado = palavra_a == palavra_b
print(resultado)
# Out:
# False

# %% [markdown]
# <ul>
# <li><strong>comparador de diferenca(!=):</strong>
# </ul>
# <br> verifica se cada caracter pertencente ao string são diferentes levando em conta a posição também.

# %%
palavra_a = 'quadrado'
palavra_b = 'quadrado'
resultado = palavra_a != palavra_b
print(resultado)
# Out:
# False

# %%
palavra_a = 'quadrado'
palavra_b = 'retangulo'
resultado = palavra_a != palavra_b
print(resultado)
# Out:
# True

# %%
palavra_a = 'quadrado'
palavra_b = 'Quadrado'
resultado = palavra_a != palavra_b
print(resultado)
# Out:
# True

# %% [markdown]
# Obs.: leve em consideração que os operadores verificam diferenças entre letras maiusculas e minusculas, outra caracteristica é que existem caracteres especiais que podem parecer equivalentes porem eles tem um código diferente e o operador leva isso em consideração também.

# %% [markdown]
# # Comparador "is" ou "é":

# %% [markdown]
# No python todas as variaveis são consideradas objetos e cada objeto possui suas caracteristicas especificas. O operador is ele leva em conta isso no momento de fazer a comparação.

# %% [markdown]
# Exemplos:

# %%
a = 1
b = 1.0
print("comparacao com == :")
print(a==b)
print("comparacao com is:")
print(a is b)
# Out:
# comparacao com == :
# True
# comparacao com is:
# False

# %% [markdown]
# Veja que o comparador == faz a comparação somente do valor atribuido as duas variaveis, e o is compara o objeto. Como a é um inteiro(<strong>int</strong>) e o b é um numero real (<strong>float</strong>)) o is retorna um <strong>False</strong>.

# %% [markdown]
# O equivalente negativo funciona de maneira parecida <strong>!=</strong> e o <strong>is not</strong>. Exemplo:

# %%
a = 1
b = 1.0
print("comparacao com != :")
print(a!=b)
print("comparacao com is:")
print(a is not b)
# Out:
# comparacao com != :
# False
# comparacao com is:
# True

# %% [markdown]
# # Resumo

# %% [markdown]
# <ul>
# <li><strong>Operadores aritméticos: </strong>
# </ul>
# <br> a =10
# <br> b =20

# %% [markdown]
# <table class="table table-bordered">
# <tbody><tr>
# <th style="text-align:center;width:10%">Operador</th>
# <th style="text-align:center;width:45%">Descrição</th>
# <th style="text-align:center;">Exemplo</th>
# </tr>
# <tr>
# <td class="ts">+</td>
# <td>Adição</td>
# <td class="ts">a + b = 30</td>
# </tr>
# <tr>
# <td class="ts">-</td>
# <td>Subtração </td>
# <td class="ts">a – b = -10</td>
# </tr>
# <tr>
# <td class="ts">*</td>
# <td>Multiplicação</td>
# <td class="ts">a * b = 200</td>
# </tr>
# <tr>
# <td class="ts">/ </td>
# <td>Divisão</td>
# <td class="ts">b / a = 2</td>
# </tr>
# <tr>
# <td class="ts">%</td>
# <td>Modulo(Resto)</td>
# <td class="ts">b % a = 0</td>
# </tr>
# <tr>
# <td class="ts">**</td>
# <td>Exponenciação</td>
# <td class="ts">a**b =10 to the power 20</td>
# </tr>
# <tr>
# <td class="ts">//</td>
# <td> Divisão inteira</td>
# <td class="ts">9//2 = 4 and 9.0//2.0 = 4.0, -11//3 = -4, -11.0//3 = -4.0</td>
# </tr>
# </tbody>

# %% [markdown]
# <ul>
# <li><strong>Operadores de comparação: </strong>
# </ul>
# <br> a =10
# <br> b =20

# %% [markdown]
# <table class="table table-bordered">
# <tbody><tr>
# <th style="text-align:center;width:10%">Operador</th>
# <th style="text-align:center;width:45%">Descrição</th>
# <th style="text-align:center;">Exemplo</th>
# </tr>
# <tr>
# <td class="ts">==</td>
# <td>equivalente a </td>
# <td class="ts">(a == b) is not true.</td>
# </tr>
# <tr>
# <td class="ts">!=</td>
# <td>diferente de </td>
# <td class="ts">(a != b) is true.</td>
# </tr>
# <td class="ts">&gt;</td>
# <td>maior</td>
# <td class="ts">(a &gt; b) is not true.</td>
# </tr>
# <tr>
# <td class="ts">&lt;</td>
# <td>menor</td>
# <td class="ts">(a &lt; b) is true.</td>
# </tr>
# <tr>
# <td class="ts">&gt;=</td>
# <td>maior igual</td>
# <td class="ts">(a &gt;= b) is not true.</td>
# </tr>
# <tr>
# <td class="ts">&lt;=</td>
# <td>menor igual</td>
# <td class="ts">(a &lt;= b) is true.</td>
# </tr>
# </tbody></table>

# %% [markdown]
# Tabelas traduzidas de :https://www.tutorialspoint.com/python/python_basic_operators.htm

# %% [markdown]
# # Referências

# %% [markdown]
# <strong>Em português</strong>
# <br>blog sobre operadores aritméticos mínimos:
# <br> http://excript.com/python/operador-aritmetico-em-python.html
# <br>blog sobre comparadores mínimos:
# <br> http://excript.com/python/operadores-logicos-python.html
# <br>
# <strong>Em inglês</strong>
# <br>Operadores basicos:
# <br> https://www.tutorialspoint.com/python/python_basic_operators.htm
# <br>Operadores padrões do python e como definir novos:
# <br> https://docs.python.org/3.4/library/operator.html
